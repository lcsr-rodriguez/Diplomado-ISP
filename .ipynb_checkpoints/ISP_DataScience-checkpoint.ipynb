# %% [markdown]
# # Proyecto de Grado - Ciencia de Datos
# # Universidad Libre Cali
# ## Leiner Ceballos Rodriguez
# ## David Cespedes

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import seaborn as sns
from scipy.stats import mode

# %%
tbl_facturas = pd.read_excel("TBL_FACTURAS.xlsx")

# %%
tbl_facturas
# Out:
#        PREFIJO  CONSECUTIVO  ID_FACTURA  SUCURSAL  CLIENTE    TOTAL  \
# 0           BT            1           1         3      304   5200.0
# 1           BT            2           2         3      303   5200.0
# 2          BT_            3          73         3      307  18200.0
# 3          BT_            4          74         3       75  60000.0
# 4          BT_            5          75         3       76  60000.0
# ...        ...          ...         ...       ...      ...      ...
# 129064      FE        53830      132628        16     8978  59000.0
# 129065      FE        53831      132629        16     9272  59000.0
# 129066      FE        53832      132630         2     8168  29000.0
# 129067      FE        53833      132631         2     3976  64000.0
# 129068      FE        53834      132632         2     8680  55000.0
#
#             FECHA  CONTRATO   F_CREADO  USUARIO
# 0      2013-07-01       NaN 2013-07-01        3
# 1      2013-07-01       NaN 2013-07-01        3
# ...

# %%
tbl_sucursales = pd.read_excel("TBL_SUCURSALES.xlsx")

# %%
tbl_facturas.columns
# Out:
# Index(['PREFIJO', 'CONSECUTIVO', 'ID_FACTURA', 'SUCURSAL', 'CLIENTE', 'TOTAL',
#        'FECHA', 'CONTRATO', 'F_CREADO', 'USUARIO'],
#       dtype='object')

# %%
tbl_sucursales.columns
# Out:
# Index(['ID_SUCURSAL', 'NOMBRE_SUCURSAL', 'DIRECCION', 'CIUDAD', 'ZONA',
#        'LONGITUD', 'LATITUD', 'COORDENADAS'],
#       dtype='object')

# %%
# Unión entre ambos DataFrames
merged_inner = pd.merge(left=tbl_facturas,right=tbl_sucursales, left_on='SUCURSAL', right_on='ID_SUCURSAL')

# %%
merged_inner.shape
merged_inner
# Out:
#        PREFIJO  CONSECUTIVO  ID_FACTURA  SUCURSAL  CLIENTE    TOTAL  \
# 0           BT            1           1         3      304   5200.0
# 1           BT            2           2         3      303   5200.0
# 2          BT_            3          73         3      307  18200.0
# 3          BT_            4          74         3       75  60000.0
# 4          BT_            5          75         3       76  60000.0
# ...        ...          ...         ...       ...      ...      ...
# 129064      FE        53827      132625        16     6936  50000.0
# 129065      FE        53828      132626        16     6991  50000.0
# 129066      FE        53829      132627        16     8575  59000.0
# 129067      FE        53830      132628        16     8978  59000.0
# 129068      FE        53831      132629        16     9272  59000.0
#
#             FECHA  CONTRATO   F_CREADO  USUARIO  ID_SUCURSAL  \
# 0      2013-07-01       NaN 2013-07-01        3            3
# ...

# %%
# Convierte el objeto en DataFrame
df = pd.DataFrame(merged_inner)
df.head()
# Out:
#   PREFIJO  CONSECUTIVO  ID_FACTURA  SUCURSAL  CLIENTE    TOTAL      FECHA  \
# 0      BT            1           1         3      304   5200.0 2013-07-01
# 1      BT            2           2         3      303   5200.0 2013-07-01
# 2     BT_            3          73         3      307  18200.0 2013-07-02
# 3     BT_            4          74         3       75  60000.0 2013-07-02
# 4     BT_            5          75         3       76  60000.0 2013-07-02
#
#    CONTRATO   F_CREADO  USUARIO  ID_SUCURSAL NOMBRE_SUCURSAL  \
# 0       NaN 2013-07-01        3            3        QUEREMAL
# 1       NaN 2013-07-01        3            3        QUEREMAL
# 2       NaN 2013-07-02        3            3        QUEREMAL
# 3       NaN 2013-07-02        2            3        QUEREMAL
# 4       NaN 2013-07-02        2            3        QUEREMAL
#
#             DIRECCION  CIUDAD    ZONA  LONGITUD    LATITUD  \
# 0  CARRERA 10 # 7 -13    1133  CENTRO  3.523325 -76.712229
# ...

# %% [markdown]
# ### Se limpian los datos vacios o nulos

# %%
# ¿Hay datos nulos?
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129069 entries, 0 to 129068
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   PREFIJO          129069 non-null  object
#  1   CONSECUTIVO      129069 non-null  int64
#  2   ID_FACTURA       129069 non-null  int64
#  3   SUCURSAL         129069 non-null  int64
#  4   CLIENTE          129069 non-null  int64
#  5   TOTAL            129069 non-null  float64
#  6   FECHA            129069 non-null  datetime64[ns]
#  7   CONTRATO         53640 non-null   float64
#  8   F_CREADO         129069 non-null  datetime64[ns]
#  9   USUARIO          129069 non-null  int64
#  10  ID_SUCURSAL      129069 non-null  int64
#  11  NOMBRE_SUCURSAL  129069 non-null  object
#  12  DIRECCION        128106 non-null  object
#  13  CIUDAD           129069 non-null  int64
#  14  ZONA             129069 non-null  object
#  15  LONGITUD         129069 non-null  float64
# ...

# %% [markdown]
# ### Algunos datos de la base de datos son nulos o NaN, debemos cambiarlo para tener una base de datos uniforme

# %%
df['CONTRATO'].fillna(0, inplace = True)

df['DIRECCION'].fillna("NO TIENE", inplace = True)

# %% [markdown]
# ### Con el código anterior reemplazamos el valor nulo en los datos por un 0, támbien se puede reemplazar por el promedio de la columna si fuera un campo de valores o eliminar las filas con datos nulos

# %%
# Contenido de la estructura corregida
df.head()
# Out:
#   PREFIJO  CONSECUTIVO  ID_FACTURA  SUCURSAL  CLIENTE    TOTAL      FECHA  \
# 0      BT            1           1         3      304   5200.0 2013-07-01
# 1      BT            2           2         3      303   5200.0 2013-07-01
# 2     BT_            3          73         3      307  18200.0 2013-07-02
# 3     BT_            4          74         3       75  60000.0 2013-07-02
# 4     BT_            5          75         3       76  60000.0 2013-07-02
#
#    CONTRATO   F_CREADO  USUARIO  ID_SUCURSAL NOMBRE_SUCURSAL  \
# 0       0.0 2013-07-01        3            3        QUEREMAL
# 1       0.0 2013-07-01        3            3        QUEREMAL
# 2       0.0 2013-07-02        3            3        QUEREMAL
# 3       0.0 2013-07-02        2            3        QUEREMAL
# 4       0.0 2013-07-02        2            3        QUEREMAL
#
#             DIRECCION  CIUDAD    ZONA  LONGITUD    LATITUD  \
# 0  CARRERA 10 # 7 -13    1133  CENTRO  3.523325 -76.712229
# ...
